# %% [markdown]
# ### 14. Longest Common Prefix
#
# <!-- <iframe src="https://leetcode.com/problems/longest-common-prefix/description/" width="95%%" height="600" style="display: block; margin: auto;></iframe> -->
#
# <div><div class="elfjS" data-track-load="description_content"><p>Write a function to find the longest common prefix string amongst an array of strings.</p>
#
# <p>If there is no common prefix, return an empty string <code>""</code>.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <pre><strong>Input:</strong> strs = ["flower","flow","flight"]
# <strong>Output:</strong> "fl"
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre><strong>Input:</strong> strs = ["dog","racecar","car"]
# <strong>Output:</strong> ""
# <strong>Explanation:</strong> There is no common prefix among the input strings.
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= strs.length &lt;= 200</code></li>
# 	<li><code>0 &lt;= strs[i].length &lt;= 200</code></li>
# 	<li><code>strs[i]</code> consists of only lowercase English letters if it is non-empty.</li>
# </ul>
# </div></div>
#
# <h5>Topic</h5>
# <p>Array
# String
# Trie</p>
# <h5>Companies</h5>
# <p>
# <h6>0 - 3 months</h6>
# Google
# 43
# Meta
# 22
# Amazon
# 21
# Bloomberg
# 10
# Microsoft
# 7
# Apple
# 6
# Revolut
# 3
# Adobe
# 2
# Palo Alto Networks
# 2
# Quora
# 2
# <h6>0 - 6 months</h6>
# TikTok
# 3
# SAP
# 3
# tcs
# 2
# Target
# 2
# Visa
# 2
# Yahoo
# 2
# Nokia
# 2
# Fractal Analytics
# 2
# HSBC
# 2
# CME Group
# 2
# <h6>6 months ago</h6>
# Uber
# 11
# Zoho
# 10
# Accenture
# 9
# Oracle
# 8
# IBM
# 6
# EPAM Systems
# 6
# Turing
# 6
# Walmart Labs
# 4
# Infosys
# 3
# Roblox
# 3
# </p>
# <h5>Hint 1</h5>
# <p></p>
# <h5>Hint 2</h5>
# <p></p>
# <h5>Hint 3</h5>
# <p></p>

# %% [markdown]
# <img src="./docs/0014/0014-02.png" width="90%" height="auto" style="display: block; margin: auto;">

# %%
class Solution:
    # Time: O(S)
    # Space: O(1)
    def longestCommonPrefix(self, strs: list[str]) -> str:
        prefix = strs[0]

        for i in range(1, len(strs)):
            curr = strs[i]

            if not prefix or not curr or prefix[0] != curr[0]:
                return ""

            min_len = min(len(prefix), len(curr))
            prefix = prefix[:min_len]
            curr = curr[:min_len]

            while prefix:
                if prefix == curr:
                    break
                prefix = prefix[:-1]
                curr = curr[:-1]

                if not prefix:
                    return ""
        return prefix

# %%
s = Solution()

tests = [
    (["flower", "flow", "flight"], "fl"),
    (["dog", "racecar", "car"], ""),
    (["interspecies", "interstellar", "interstate"], "inters"),
    (["cir", "car"], "c"),
    (["alone"], "alone"),  # single element
    (["", "b"], ""),  # empty string in list
    (["Case", "case"], ""),  # case-sensitive
    (["ab", "a"], "a"),
]

for strs, expected in tests:
    got = s.longestCommonPrefix(strs)
    assert got == expected, f"For {strs} expected {expected!r}, got {got!r}"

print("✅ All tests passed")
