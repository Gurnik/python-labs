# %% [markdown]
# ### 70. Climbing Stairs
#
# <!-- <iframe src="https://leetcode.com/problems/climbing-stairs/description//" width="95%%" height="600" style="display: block; margin: auto;></iframe> -->
#
# <div><div class="elfjS" data-track-load="description_content"><p>You are climbing a staircase. It takes <code>n</code> steps to reach the top.</p>
#
# <p>Each time you can either climb <code>1</code> or <code>2</code> steps. In how many distinct ways can you climb to the top?</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <pre><strong>Input:</strong> n = 2
# <strong>Output:</strong> 2
# <strong>Explanation:</strong> There are two ways to climb to the top.
# 1. 1 step + 1 step
# 2. 2 steps
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre><strong>Input:</strong> n = 3
# <strong>Output:</strong> 3
# <strong>Explanation:</strong> There are three ways to climb to the top.
# 1. 1 step + 1 step + 1 step
# 2. 1 step + 2 steps
# 3. 2 steps + 1 step
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= n &lt;= 45</code></li>
# </ul>
# </div></div>
#
# <h5>Topics</h5>
# <p>
# Math
# Dynamic Programming
# Memoization
# </p>
# <h5>Companies</h5>
# <p>
# <h6>0 - 3 months</h6>
# Google
# 12
# Amazon
# 9
# Meta
# 5
# Microsoft
# 3
# Bloomberg
# 3
# Grammarly
# 3
# Zoho
# <h6>0 - 6 months</h6>
# tcs
# <h6>6 months ago</h6>
# Apple
# 20
# Adobe
# 16
# Accenture
# 15
# Yahoo
# 9
# Uber
# 7
# TikTok
# 6
# J.P. Morgan
# 5
# Goldman Sachs
# 5
# Infosys
# 4
# Accolite
# </p>
# <h5>Hint 1</h5>
# <p>To reach nth step, what could have been your previous steps? (Think about the step sizes)</p>
# <h5>Hint 2</h5>
# <p></p>
# <h5>Hint 3</h5>
# <p></p>

# %% [markdown]
# <img src="./docs/0070/0070-02.png" width="90%" height="auto" style="display: block; margin: auto;">
# <img src="./docs/0070/0070-03.png" width="90%" height="auto" style="display: block; margin: auto;">
# <img src="./docs/0070/0070-04.png" width="90%" height="auto" style="display: block; margin: auto;">
# <img src="./docs/0070/0070-05.png" width="90%" height="auto" style="display: block; margin: auto;">

# %%
class Solution:
    # Time: O(n)
    # Space: O(n)
    def climbStairs(self, n: int) -> int:
        if n == 1:
            return 1
        dp = [0 for _ in range(n + 1)]
        dp[1] = 1
        dp[2] = 2
        for i in range(3, n + 1):
            dp[i] = dp[i - 1] + dp[i - 2]
        return dp[n]

# %%
s = Solution()


# quick Fibonacci helper for the property check
def fib(k: int) -> int:
    a, b = 0, 1
    for _ in range(k):
        a, b = b, a + b
    return a


# Exact values
cases = [
    (1, 1),
    (2, 2),
    (3, 3),
    (4, 5),
    (5, 8),
    (10, 89),
    (20, 10946),
    (30, 1346269),
    (45, 1836311903),  # LeetCode max typical constraint
]
for n, expected in cases:
    got = s.climbStairs(n)
    assert got == expected, f"n={n}: expected {expected}, got {got}"

# Property: climbStairs(n) == fib(n+1)
for n in range(1, 46):
    assert s.climbStairs(n) == fib(n + 1), f"n={n}: not equal to fib(n+1)"

# Monotonicity: strictly increasing for n>=1
prev = s.climbStairs(1)
for n in range(2, 15):
    cur = s.climbStairs(n)
    assert cur > prev, f"n={n}: sequence not increasing (prev={prev}, cur={cur})"
    prev = cur

print("✅ climbStairs assertions passed")
